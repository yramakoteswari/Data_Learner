# %% [markdown]
# Data manipualtion tasks
# filtering data
# sorting data
# group by aggregates
# adding new columns
# handling dates
# merging dataframes
# treating missing values

# %%
#import packages
import os
import pandas as pd
import numpy as np

# %%
#load the data set stores
store = pd.read_csv("Downloads//Store.csv",encoding='latin')#accented characters

# %%
#number of observations
store.shape[0]
# Out:
# 9994

# %%
#information about the columns /variables in a data set
store.shape
# Out:
# (9994, 21)

# %%
#first three observations from data set
store.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 1       2  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 2       3  CA-2013-138688  6/13/2013   6/17/2013  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %%
store.info()#information about each variable
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
# Row ID           9994 non-null int64
# Order ID         9994 non-null object
# Order Date       9994 non-null object
# Ship Date        9994 non-null object
# Ship Mode        9994 non-null object
# Customer ID      9994 non-null object
# Customer Name    9994 non-null object
# Segment          9994 non-null object
# Country          9994 non-null object
# City             9994 non-null object
# State            9994 non-null object
# Postal Code      9994 non-null int64
# Region           9994 non-null object
# Product ID       9994 non-null object
# Category         9994 non-null object
# Sub-Category     9994 non-null object
# Product Name     9994 non-null object
# Sales            9994 non-null float64
# Quantity         9994 non-null int64
# Discount         9994 non-null float64
# Profit           9994 non-null float64
# dtypes: float64(3), int64(3), object(15)
# ...

# %%
#object(string variables) categorical
store.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
store.tail(2)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9992    9993  CA-2014-121258  2/27/2014   3/4/2014  Standard Class
# 9993    9994  CA-2014-119914   5/5/2014  5/10/2014    Second Class
#
#      Customer ID Customer Name   Segment        Country         City  ...  \
# 9992    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.60         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.16         2
#
#       Discount  Profit
# 9992       0.0  13.320
# 9993       0.0  72.948
#
# ...

# %%
#Count the number of missing values
store.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
#Summary statistics for numerical variables
store.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
store[['Sales','Postal Code']].describe()
# Out:
#               Sales   Postal Code
# count   9994.000000   9994.000000
# mean     229.858001  55190.379428
# std      623.245101  32063.693350
# min        0.444000   1040.000000
# 25%       17.280000  23223.000000
# 50%       54.490000  56430.500000
# 75%      209.940000  90008.000000
# max    22638.480000  99301.000000

# %%
#finding out how many cities are the orders being delivered to
#we have to print the contents of the city column
cities=store['City']
print(type(cities))
print(len(cities))
# Out:
# <class 'pandas.core.series.Series'>
# 9994

# %%
cities=store.City
print(len(cities))
# Out:
# 9994

# %%
print(len(set(cities)))
# Out:
# 531

# %%
#unique cities uniques method how many unique cities package has delivered
cities_uni=store['City'].unique().tolist()#default type array ,unless u convert it to a lisrt
print(type(cities_uni))
print(cities_uni)
len(cities_uni)
# Out:
# <class 'list'>
# ...

# %%
#unique Levels of segment
seg=store['Segment'].unique()#.tolist()
seg
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
#Filter consumer from segment
#logical indexation
store[store['Segment']=='Consumer'].head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 1       2  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 3       4  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 5       6  CA-2011-115812    6/9/2011   6/14/2011  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 3   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 4   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 5  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
# ...

# %%
x=store[(store['Segment']=='Consumer') & (store['Country']=='United States')]
x
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 1          2  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 3          4  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 4          5  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 5          6  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2011-110422   1/22/2011   1/24/2011    Second Class
# 9990    9991  CA-2014-121258   2/27/2014    3/4/2014  Standard Class
# 9991    9992  CA-2014-121258   2/27/2014    3/4/2014  Standard Class
# 9992    9993  CA-2014-121258   2/27/2014    3/4/2014  Standard Class
# 9993    9994  CA-2014-119914    5/5/2014   5/10/2014    Second Class
#
#      Customer ID     Customer Name   Segment        Country             City  \
# ...

# %%
#query method
store.query('Segment=="Consumer"').head(2)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 1       2  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
store.query('Segment=="Consumer" and Country=="United States"').head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 1       2  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 3       4  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 5       6  CA-2011-115812    6/9/2011   6/14/2011  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 3   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 4   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 5  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
# ...

# %%
#multiple conditions
#how many orders were placed for region south and for segment consumer
#data(l1)(l2)&(l3)
#data(l2)(l2)
store[(store['Region']=="South") & (store['Segment']=="Consumer")].shape[0]
# Out:
# 838

# %%
#dataquery ("l1 and l2")
store.query('Region=="South" & Segment=="Consumer"').shape[0]
# Out:
# 838

# %%
#find how many transactions from region south had a profit >$50
store.query('Region=="South" & Profit>50' ).shape[0]
store[(store['Region']=="South")& (store['Profit']>50)].shape[0]
# Out:
# 323

# %%
store[(store['Region']=="South")& (store['Profit']>50)].shape[0]
# Out:
# 323

# %%
#write a code snippet to find out if there was any instances of packages delivered to Los Angeles
store.query('City=="Los Angeles"').shape[0]
# Out:
# 747

# %%
#how many times orders were shipped to east region
ty =store.query('Region=="East"')

# %%
#how to figure out total quantity of products shipped to the east zone
store.query('Region=="East"')['Quantity']
# Out:
# 23       2
# 27       7
# 28       2
# 29       3
# 30       2
#         ..
# 9968     2
# 9969     7
# 9981     5
# 9984    10
# 9985     4
# Name: Quantity, Length: 2848, dtype: int64

# %%
store.query('Region=="East"')['Quantity'].sum()
# Out:
# 10618

# %%
ty["Quantity"].sum()#indexing brackets , query ki codes
# Out:
# 10618

# %% [markdown]
# # Sorting

# %%
#sorting the data 
#sort_values() method to sort the values
#sort data by profit
store1=store.sort_values("Profit").head()#is in ascending order

# %%
store.sort_values("Profit",ascending=False).head()# to get in descending order
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 6826    6827  CA-2013-118689   10/3/2013  10/10/2013  Standard Class
# 8153    8154  CA-2014-140151   3/24/2014   3/26/2014     First Class
# 4190    4191  CA-2014-166709  11/18/2014  11/23/2014  Standard Class
# 9039    9040  CA-2013-117121  12/18/2013  12/22/2013  Standard Class
# 4098    4099  CA-2011-116904   9/23/2011   9/28/2011  Standard Class
#
#      Customer ID  Customer Name    Segment        Country         City  ...  \
# 6826    TC-20980   Tamara Chand  Corporate  United States    Lafayette  ...
# 8153    RB-19360   Raymond Buch   Consumer  United States      Seattle  ...
# 4190    HL-15040   Hunter Lopez   Consumer  United States       Newark  ...
# 9039    AB-10105  Adrian Barton   Consumer  United States      Detroit  ...
# 4098    SC-20095   Sanjit Chand   Consumer  United States  Minneapolis  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
#which are the most valuable customers in south region by sales
sal=store.query('Region=="South"')
sal
sal.sort_values("Sales",ascending=False).head()#head method gives only 5 rows
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2011-145317  3/18/2011  3/23/2011  Standard Class
# 8488    8489  CA-2013-158841   2/2/2013   2/4/2013    Second Class
# 683      684  US-2014-168116  11/5/2014  11/5/2014        Same Day
# 509      510  CA-2012-145352  3/16/2012  3/22/2012  Standard Class
# 4297    4298  CA-2014-129021  8/24/2014  8/27/2014    Second Class
#
#      Customer ID         Customer Name      Segment        Country  \
# 2697    SM-20320           Sean Miller  Home Office  United States
# 8488    SE-20110          Sanjit Engle     Consumer  United States
# 683     GT-14635        Grant Thornton    Corporate  United States
# 509     CM-12385  Christopher Martinez     Consumer  United States
# 4297    PO-18850       Patrick O'Brill     Consumer  United States
#
#               City  ... Postal Code  Region       Product ID         Category  \
# ...

# %%
#sort by two variables
store.sort_values(['Profit','Sales'],ascending=[False,True]).head()# if two values are same
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 6826    6827  CA-2013-118689   10/3/2013  10/10/2013  Standard Class
# 8153    8154  CA-2014-140151   3/24/2014   3/26/2014     First Class
# 4190    4191  CA-2014-166709  11/18/2014  11/23/2014  Standard Class
# 9039    9040  CA-2013-117121  12/18/2013  12/22/2013  Standard Class
# 4098    4099  CA-2011-116904   9/23/2011   9/28/2011  Standard Class
#
#      Customer ID  Customer Name    Segment        Country         City  ...  \
# 6826    TC-20980   Tamara Chand  Corporate  United States    Lafayette  ...
# 8153    RB-19360   Raymond Buch   Consumer  United States      Seattle  ...
# 4190    HL-15040   Hunter Lopez   Consumer  United States       Newark  ...
# 9039    AB-10105  Adrian Barton   Consumer  United States      Detroit  ...
# 4098    SC-20095   Sanjit Chand   Consumer  United States  Minneapolis  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
#identify top 10 customers in the south region (top 10 in terms of sale amoun t , discount)
sal.sort_values("Discount",ascending=False).head(10)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 8737    8738  CA-2014-161592    4/7/2014   4/11/2014  Standard Class
# 4796    4797  US-2013-148901   5/15/2013   5/20/2013  Standard Class
# 1906    1907  US-2013-150567   5/18/2013   5/22/2013  Standard Class
# 4724    4725  CA-2013-131968  11/12/2013  11/16/2013  Standard Class
# 8649    8650  CA-2013-164574   7/30/2013    8/4/2013  Standard Class
# 1898    1899  CA-2011-169775   8/29/2011    9/2/2011    Second Class
# 978      979  CA-2013-145499   5/31/2013    6/1/2013     First Class
# 4754    4755  CA-2014-126354    2/4/2014    2/9/2014  Standard Class
# 8644    8645  CA-2012-108259   11/8/2012  11/15/2012  Standard Class
# 5835    5836  CA-2012-101868    6/9/2012   6/16/2012  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 8737    CS-12175   Charles Sheldon    Corporate  United States
# 4796    MK-17905   Michael Kennedy    Corporate  United States
# ...

# %%
sal.sort_values("Discount")[['Customer ID','Customer Name']].head(10)# one bracket for indexation st
# Out:
#      Customer ID      Customer Name
# 0       CG-12520        Claire Gute
# 4137    DD-13570  Dorothy Dickinson
# 4159    AP-10915     Arthur Prichep
# 4172    JF-15355           Jay Fein
# 4173    JF-15355           Jay Fein
# 4174    JF-15355           Jay Fein
# 4176    RS-19765     Roland Schwarz
# 4177    RS-19765     Roland Schwarz
# 4211    PF-19120       Peter Fuller
# 4212    PF-19120       Peter Fuller

# %%
store.query("Region=='South'").sort_values(['Sales','Discount'],ascending=[False,True])['Customer Name'].head(10)
# Out:
# 2697             Sean Miller
# 8488            Sanjit Engle
# 683           Grant Thornton
# 509     Christopher Martinez
# 4297         Patrick O'Brill
# 9639             Joseph Holt
# 3280            Greg Maxwell
# 7583        Kristen Hastings
# 4093         Katrina Willman
# 1454            Mark Cousins
# Name: Customer Name, dtype: object

# %%
store.query("Region=='East'").sort_values(['Sales',"Discount"],ascending=[False,True])[['Customer Name','Customer ID']].head(10)
# Out:
#            Customer Name Customer ID
# 2623        Tom Ashbrook    TA-21385
# 4190        Hunter Lopez    HL-15040
# 4277        Bill Shonely    BS-11365
# 6425  Christopher Conant    CC-12370
# 6626    Tom Boeckenhauer    TB-21400
# 7666       Daniel Raglin    DR-12940
# 6340        Todd Sumrall    TS-21370
# 1085       Karen Daniels    KD-16270
# 1803        Joseph Airdo    JA-15970
# 8204       Keith Dawkins    KD-16495

# %%
store.sort_values('Sales')[['Region','Sales']].head()
store.sort_values('Sales')[['Region','Sales','Customer Name','Customer ID']].head()
# Out:
#        Region  Sales     Customer Name Customer ID
# 4101  Central  0.444  Zuschuss Carroll    ZC-21910
# 9292  Central  0.556    Roland Schwarz    RS-19765
# 8658  Central  0.836       Ken Brennan    KB-16600
# 4711     East  0.852     Jas O'Carroll    JO-15280
# 2106  Central  0.876     Henry Goldwyn    HG-14965

# %%
#figure out bottom 3(least valued customers based on sale amount) for all the zones
store.sort_values('Sales',ascending=False)[['Region','Sales']].tail(3)
# Out:
#        Region  Sales
# 8658  Central  0.836
# 9292  Central  0.556
# 4101  Central  0.444

# %% [markdown]
# # group by
# group by task(split the data into groups based on some criteria)

# %%
# i need the sum of sale amount for each state
state_group =store.groupby('State',as_index=False)#already we have done the group by store.groupby('State').reset_index()
#here as_index=False/reset_index()method represent dont keep state variable as index 
state_group

# %% [markdown]
# # aggregate method

# %%
sales_sum=state_group.agg({"Sales":'sum'}).head()
sales_sum
# Out:
#         State        Sales
# 0     Alabama   19510.6400
# 1     Arizona   35282.0010
# 2    Arkansas   11678.1300
# 3  California  457687.6315
# 4    Colorado   32108.1180

# %%
state_group =store.groupby('State').agg({"Sales":'sum'}).head()   #index is the state variable itself

# %%
state_group
# Out:
#                   Sales
# State
# Alabama      19510.6400
# Arizona      35282.0010
# Arkansas     11678.1300
# California  457687.6315
# Colorado     32108.1180

# %%
store.groupby('State',as_index=False).agg({'Sales':np.sum}).head()
# Out:
#         State        Sales
# 0     Alabama   19510.6400
# 1     Arizona   35282.0010
# 2    Arkansas   11678.1300
# 3  California  457687.6315
# 4    Colorado   32108.1180

# %%
store.groupby('State').agg({'Sales':np.sum,'Profit':np.max}).head()
# Out:
#                   Sales     Profit
# State
# Alabama      19510.6400  1459.2000
# Arizona      35282.0010   211.4955
# Arkansas     11678.1300   843.1706
# California  457687.6315  1906.4850
# Colorado     32108.1180   247.9960

# %%
store.groupby('State').agg({'Sales':np.sum,'Profit':np.mean}).head()
# Out:
#                   Sales     Profit
# State
# Alabama      19510.6400  94.865989
# Arizona      35282.0010 -15.303235
# Arkansas     11678.1300  66.811452
# California  457687.6315  38.171608
# Colorado     32108.1180 -35.867351

# %%
store.groupby('State').agg({'Sales':np.sum,'Profit':np.max}).reset_index().head()#reset should come after aggregation only
# Out:
#         State        Sales     Profit
# 0     Alabama   19510.6400  1459.2000
# 1     Arizona   35282.0010   211.4955
# 2    Arkansas   11678.1300   843.1706
# 3  California  457687.6315  1906.4850
# 4    Colorado   32108.1180   247.9960

# %%
store.groupby(['City','State']).agg({'Sales':'max','Profit':np.mean}).reset_index().head()
# Out:
#           City         State     Sales     Profit
# 0     Aberdeen  South Dakota    25.500   6.630000
# 1      Abilene         Texas     1.392  -3.758400
# 2        Akron          Ohio   665.408  -8.887410
# 3  Albuquerque    New Mexico   595.000  45.292007
# 4   Alexandria      Virginia  4164.050  19.913644

# %%
#store.groupby(['State','City']).agg({'Sales':'max','Profit':np.mean})
store.query('State=="Alabama"').groupby(['State','City']).agg({'Sales':'max','Profit':np.mean})
# Out:
#                       Sales      Profit
# State   City
# Alabama Auburn       900.08   75.434517
#         Decatur     1215.92   76.929854
#         Florence    1819.86   49.731780
#         Hoover       477.24    4.679325
#         Huntsville  1319.96  100.525720
#         Mobile      3040.00  197.802655
#         Montgomery  1394.95   83.465710
#         Tuscaloosa   141.96   25.505200

# %%
store.query('Region=="East"').groupby(['State','City']).agg({'Sales':'max','Profit':np.mean}).sort_values(['Sales'],ascending=False).tail()
# Out:
#                                Sales    Profit
# State         City
# New Hampshire Nashua          21.120  6.756300
# Ohio          Cuyahoga Falls  18.528 -4.191733
# Pennsylvania  Altoona         16.032 -0.591750
# New Jersey    New Brunswick    7.610  3.578350
# Ohio          Elyria           1.824 -1.398400

# %%
#average quantity sold by region
store.groupby(['Region']).agg({'Quantity':np.mean})
# Out:
#          Quantity
# Region
# Central  3.779595
# East     3.728230
# South    3.832716
# West     3.829535

# %%
store.query('Region=="East"').groupby('State')['Sales','Profit'].agg(['mean','max'])#.sort_values('Sales',ascending=False)
# Out:
#                            Sales                 Profit
#                             mean        max        mean        max
# State
# Connecticut           163.223866   1133.350   42.823071   294.6710
# Delaware              285.948635  10499.970  103.930988  5039.9856
# District of Columbia  286.502000   1379.920  105.958930   648.5624
# Maine                 158.816250    437.850   56.810775   131.3550
# Maryland              225.766886   2541.980   66.963608  1270.9900
# Massachusetts         212.106919   1737.180   50.262975   503.7822
# New Hampshire         270.093481   2249.910   63.203807   517.4793
# New Jersey            275.110092   9099.930   75.176260  2365.9818
# New York              275.599531  11199.968   65.637011  3919.9888
# Ohio                  166.861697   4499.985  -36.186304   607.6080
# Pennsylvania          198.487077   8399.976  -26.507598  1119.9968
# Rhode Island          404.070643   5399.910  130.100523  2591.9568
# ...

# %%
#find average profit by region
store.groupby(['Region']).agg({'Profit':np.mean})
# Out:
#             Profit
# Region
# Central  17.092709
# East     32.135808
# South    28.857673
# West     33.849032

# %%
store.groupby('State').agg({'Sales':'max'}).sort_values('Sales',ascending=False).head()
# Out:
#                 Sales
# State
# Florida     22638.480
# Indiana     17499.950
# Washington  13999.960
# New York    11199.968
# Delaware    10499.970

# %% [markdown]
# # Renaming the columns

# %%
store.groupby("Segment",as_index=False).agg({'Discount':np.mean}).rename(columns={"Discount":"Average Discount"})
# Out:
#        Segment  Average Discount
# 0     Consumer          0.158141
# 1    Corporate          0.158228
# 2  Home Office          0.147128

# %%
store.groupby("Segment",as_index=False).agg({'Discount':np.mean,'Sales':'max'}).rename(columns={"Discount":"Average Discount",'Sales':'Max Sales'})
# Out:
#        Segment  Average Discount  Max Sales
# 0     Consumer          0.158141   13999.96
# 1    Corporate          0.158228   17499.95
# 2  Home Office          0.147128   22638.48

# %%
store.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 1       2  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 2       3  CA-2013-138688   6/13/2013   6/17/2013    Second Class    DV-13045
# 3       4  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#which segment of customers get the max discount percentage percentage per segment

data1=store.groupby("Segment",as_index=False).agg({'Discount':np.max})
print(store.groupby("Segment",as_index=False).agg({'Discount':np.max}).shape[0]/store.shape[0])
print(data1['Discount']/store.shape[0])
# Out:
# 0.0003001801080648389
# 0    0.00008
# 1    0.00008
# 2    0.00008
# Name: Discount, dtype: float64

# %%
#wat are the top 5 categories that give maximum profit
store.groupby("Category",as_index=False).agg({"Profit":np.max}).sort_values("Profit",ascending=False)
# Out:
#           Category    Profit
# 2       Technology  8399.976
# 1  Office Supplies  4946.370
# 0        Furniture  1013.127

# %%
#Adding new columns 
#Comaring sales per order with the average sales?
store["Hi_Low"]=(store['Sales'])/(store['Sales'].mean())
store.head(2)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 1       2  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  South
# 1   Claire Gute  Consumer  United States  Henderson  ...  South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        3
#
#    Discount    Profit    Hi_Low
# 0       0.0   41.9136  1.139660
# 1       0.0  219.5820  3.184314
#
# [2 rows x 22 columns]

# %%
#Create cost price variable
store["Cost"]=(store['Sales'])-(store['Profit'])

# %%
#Apply method 
#Wat is the total sales, quantity ,discount,Profit across Total US.
def get_sum(x):
    return np.sum(x) # In this function we were finding out the sum of all column values 
store[["Sales","Quantity","Discount","Profit"]].apply(get_sum,axis=0)#Function is to be applied on each column on data.
                                                                    #along the rows
# Out:
# Sales       2.297201e+06
# Quantity    3.787300e+04
# Discount    1.561090e+03
# Profit      2.863970e+05
# dtype: float64

# %%
#map function
store['Sales'].map(get_sum)
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64

# %%
store['profit_flag']=(store['Profit']>5000).map({True:'HIGH',False:'LOW'})
store.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 1       2  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 2       3  CA-2013-138688  6/13/2013   6/17/2013  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ...  \
# 0      Claire Gute   Consumer  United States    Henderson  ...
# 1      Claire Gute   Consumer  United States    Henderson  ...
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# 2  Office Supplies        Labels
#
#                                         Product Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        3
# ...

# %% [markdown]
# # working with date time functions

# %%
# Datatime
#find how much time it takes to place an order and ship the product
# to _datatime() helps to convert an object into date object
store['Order Date']=pd.to_datetime(store['Order Date'])
store['Ship Date']=pd.to_datetime(store['Ship Date'])
store['Duration']=store['Ship Date']-store['Order Date']

# %%
import pandas as pd
pd.to_datetime('today')
# Out:
# Timestamp('2020-02-25 14:11:21.778099')

# %%
#pd.timestamp('today')
pd.datetime.now()
# Out:
# datetime.datetime(2020, 2, 25, 14, 11, 21, 795728)

# %%
store.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
def sales(y):
    if y>3000 :
        return "High"
    else:
        return "Low"

# %%
store['Sales'].map(sales)
# Out:
# 0       Low
# 1       Low
# 2       Low
# 3       Low
# 4       Low
#        ...
# 9989    Low
# 9990    Low
# 9991    Low
# 9992    Low
# 9993    Low
# Name: Sales, Length: 9994, dtype: object

# %%
#how many times has it taken more than 5 days from placing an order to shipping 
xyz=store[store['Duration']>'5 days'].shape[0]
xyz
# Out:
# 1822

# %%
# what is the probability of shipping time exceeding 5 days
xyz/store.shape[0]     #if variable name is like (order date ) cannot apply query method
# Out:
# 0.18230938563137883

# %%
# what are the shipping category for which shipping is greater than 5 days
#store.groupby('xyz')#.agg

# %%
store['Category'].unique
# Out:
# <bound method Series.unique of 0             Furniture
# 1             Furniture
# 2       Office Supplies
# 3             Furniture
# 4       Office Supplies
#              ...
# 9989          Furniture
# 9990          Furniture
# 9991         Technology
# 9992    Office Supplies
# 9993    Office Supplies
# Name: Category, Length: 9994, dtype: object>

# %%
store[store['Duration']>'5 days'].groupby("Category").agg({"Category":'size'}) #when we need count( size)
# Out:
#                  Category
# Category
# Furniture             365
# Office Supplies      1131
# Technology            326

# %%
store[store['Duration']>'5 days']["Category"]
# Out:
# 3             Furniture
# 4       Office Supplies
# 16      Office Supplies
# 53      Office Supplies
# 54           Technology
#              ...
# 9972    Office Supplies
# 9982    Office Supplies
# 9983         Technology
# 9984    Office Supplies
# 9985    Office Supplies
# Name: Category, Length: 1822, dtype: object

# %%
# which are the cities to which the shipping time is 1 day (Display only the cities)
store[store['Duration']=='1 day']["City"].shape[0]
# Out:
# 368

# %%
store[store['Duration']=='1 day'].groupby('City').agg({'City':'size'})
# Out:
#               City
# City
# Allen            2
# Altoona          2
# Ann Arbor        1
# Antioch          1
# Apple Valley     2
# ...            ...
# Waterbury        3
# Westminster      1
# Wilmington       5
# Woodstock        2
# Yuma             1
#
# [95 rows x 1 columns]

# %%
store['Ship Date'].head()
# Out:
# 0   2013-11-12
# 1   2013-11-12
# 2   2013-06-17
# 3   2012-10-18
# 4   2012-10-18
# Name: Ship Date, dtype: datetime64[ns]

# %%
#changing date formats
store['Ship Date'].dt.strftime("%d/%m/%Y").head()
# Out:
# 0    12/11/2013
# 1    12/11/2013
# 2    17/06/2013
# 3    18/10/2012
# 4    18/10/2012
# Name: Ship Date, dtype: object

# %%
#http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas

# %%
store['Order Date'].dt.strftime('%y-%m-%d %H:%M').head(2)
# Out:
# 0    13-11-09 00:00
# 1    13-11-09 00:00
# Name: Order Date, dtype: object

# %%
df=pd.DataFrame()
#create 6 dates
df['time'] = pd.date_range('2/5/2019', periods = 6,freq ='2H') 
print(df['time'])
#H :hours , T :minutes ,S:seconds ,M:months ,D : days ,Y:years
# Out:
# 0   2019-02-05 00:00:00
# 1   2019-02-05 02:00:00
# 2   2019-02-05 04:00:00
# 3   2019-02-05 06:00:00
# 4   2019-02-05 08:00:00
# 5   2019-02-05 10:00:00
# Name: time, dtype: datetime64[ns]

# %%
#extract features - year month day hour minute
df['year'] = df['time'].dt.year
df['month'] = df['time'].dt.month
df['day'] = df['time'].dt.day
df['hour'] = df['time'].dt.hour
df['minute'] = df['time'].dt.minute
print(df)
# Out:
#                  time  year  month  day  hour  minute
# 0 2019-02-05 00:00:00  2019      2    5     0       0
# 1 2019-02-05 02:00:00  2019      2    5     2       0
# 2 2019-02-05 04:00:00  2019      2    5     4       0
# 3 2019-02-05 06:00:00  2019      2    5     6       0
# 4 2019-02-05 08:00:00  2019      2    5     8       0
# 5 2019-02-05 10:00:00  2019      2    5    10       0

# %%
# extract dAYS OF WEEK and then print
#weekday returns numerical value : 0-'monday' , 6-'sunday'
print(df['time'].dt.weekday)
print(df['time'].dt.weekday_name)
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: time, dtype: int64
# 0    Tuesday
# 1    Tuesday
# 2    Tuesday
# 3    Tuesday
# 4    Tuesday
# 5    Tuesday
# Name: time, dtype: object

# %% [markdown]
# # combining dataframes using concat function

# %%
data1=pd.read_csv("Downloads//Sales_Sep.csv")
data2=pd.read_csv("Downloads//Sales_Oct.csv")

# %%
data1.head()
# Out:
#   Cust_ID  Sales_Amount
# 0     CS1          1000
# 1     CS2           900
# 2     CS3           875
# 3     CS4           230
# 4     CS5           987

# %%
data2.head()
# Out:
#   Cust_ID  Sales_Amount
# 0     CS1          1000
# 1     CS2           890
# 2     CS3           900
# 3     CS4           450
# 4     CS8           980

# %%
#concatenate 
row_concat = pd.concat([data1,data2]) 
row_concat.head(12)
# Out:
#   Cust_ID  Sales_Amount
# 0     CS1          1000
# 1     CS2           900
# 2     CS3           875
# 3     CS4           230
# 4     CS5           987
# 5     CS6           560
# 6     CS7           455
# 7     CS8           350
# 8     CS9           874
# 9    CS10           289
# 0     CS1          1000
# 1     CS2           890

# %%
#export files to working directory
row_concat.to_csv("Downloads/rowfile.csv")

# %% [markdown]
# # combining dataframes using merge function

# %%
#merging dataframes
df1=pd.DataFrame({'CustomerID':[1,2,3,4,5,6],'Product':['Television','Television','Television','earphones','earphones','earphones']})
df2= pd.DataFrame({'CustomerID':[2,4,6],'State':['Texas','Texas','Texas']})

# %%
data1
# Out:
#   Cust_ID  Sales_Amount
# 0     CS1          1000
# 1     CS2           900
# 2     CS3           875
# 3     CS4           230
# 4     CS5           987
# 5     CS6           560
# 6     CS7           455
# 7     CS8           350
# 8     CS9           874
# 9    CS10           289

# %%
data2
# Out:
#    Cust_ID  Sales_Amount
# 0      CS1          1000
# 1      CS2           890
# 2      CS3           900
# 3      CS4           450
# 4      CS8           980
# 5      CS9           100
# 6     CS10           985
# 7     CS11          1900
# 8     CS12          2100
# 9     CS13          3000
# 10    CS14          3500
# 11    CS15          4000

# %%
#outer join :every records will appear
#pd.merge(df1,df2,how='outer',on='Customer')
pd.merge(data1,data2,how='outer',on='Cust_ID') # all values no overlapping values no repetition
pd.merge(data1,data2,how='inner',on='Cust_ID') #only common data
# Out:
#   Cust_ID  Sales_Amount_x  Sales_Amount_y
# 0     CS1            1000            1000
# 1     CS2             900             890
# 2     CS3             875             900
# 3     CS4             230             450
# 4     CS8             350             980
# 5     CS9             874             100
# 6    CS10             289             985

# %%
pd.merge(data1,data2,how='left',on='Cust_ID')# dataframe data1 will be kept as it is and on basis of common variable merge dataframe data2
# Out:
#   Cust_ID  Sales_Amount_x  Sales_Amount_y
# 0     CS1            1000          1000.0
# 1     CS2             900           890.0
# 2     CS3             875           900.0
# 3     CS4             230           450.0
# 4     CS5             987             NaN
# 5     CS6             560             NaN
# 6     CS7             455             NaN
# 7     CS8             350           980.0
# 8     CS9             874           100.0
# 9    CS10             289           985.0

# %%
pd.merge(data1,data2,how='right',on='Cust_ID')
# Out:
#    Cust_ID  Sales_Amount_x  Sales_Amount_y
# 0      CS1          1000.0            1000
# 1      CS2           900.0             890
# 2      CS3           875.0             900
# 3      CS4           230.0             450
# 4      CS8           350.0             980
# 5      CS9           874.0             100
# 6     CS10           289.0             985
# 7     CS11             NaN            1900
# 8     CS12             NaN            2100
# 9     CS13             NaN            3000
# 10    CS14             NaN            3500
# 11    CS15             NaN            4000

# %%
data1.drop('Cust_ID',axis=1) # axis=1 : along the columns
# Out:
#    Sales_Amount
# 0          1000
# 1           900
# 2           875
# 3           230
# 4           987
# 5           560
# 6           455
# 7           350
# 8           874
# 9           289

# %% [markdown]
# # Working with string manipulation functions

# %%
st=pd.read_csv("Downloads//Strings.csv")
st
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-98-4aae2e3de102> in <module>
# ----> 1 st=pd.read_csv("Downloads//Strings.csv")
#       2 st
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
st['Income_M']=st['Income_M'].str.replace("Rs","").str.replace("/-","")
print(st.head())

# %%
#find mean of income

# %%
st["Income_M"]=st['Income_M'].str.replace("/-","")
print(st.head())

# %%
st.Income_M=pd.to_numeric(st.Income_M)
st['Income_M'].mean()

# %% [markdown]
# # handling character using dummies

# %%
dat=pd.read_csv("Downloads//medal.csv",encoding="latin")

# %%
dat

# %%
dummies=pd.get_dummies(dat)
dummies.head()

# %% [markdown]
# # handling missing values

# %%
#counting the number of missing values in each column
dat_m=pd.read_csv('Downloads//credit_history.csv',na_values=['Missing',""])

# %%
dat_m.isnull().sum()
#if there are any blank spaces or keyword missing in the source csv files ,they will be replaced with NaN

# %%
dat_m.head()

# %%
# for categorical by mode and numrical mean and median
#median 50%tile
#replacing or impute missing values
#dat_m['years']=dat_m['years'].fillna(np.median(dat_m['years']))
dat_m['years']=dat_m['years'].fillna(dat_m['years'].median())

# %%
dat_m['years'].describe()

# %%
dat_m['years'].median()

# %%
dat_m.shape[0]

# %% [markdown]
# # Reshaping data frames

# %%
import pandas as pd
dt=pd.read_json("Downloads/Datasets/amsterdam.json")

# %%
dt['price']=dt['price'].apply(lambda x: x.replace(',',''))

# %%
dt['price']=dt['price'].apply(lambda x: x.replace('$',''))

# %%
dt['price'] = dt['price'].astype(float)

# %%
dt.drop(dt[dt['price'] > 440.0].index, inplace = True)

# %%
dat=dt.dropna()

# %%
dat.isnull().sum()
# Out:
# host_listings_count               0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# guests_included                   0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# price                             0
# latitude                          0
# longitude                         0
# room_type                         0
# instant_bookable                  0
# dtype: int64

# %%
from math import radians, cos, sin, asin, sqrt
def haversine(lon1, lat1, lon2, lat2):
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    km = 6367 * c
    return km
