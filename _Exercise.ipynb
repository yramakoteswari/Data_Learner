# %% [markdown]
# # Data Manipulation with Pandas- Exercise 1

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
#import packages
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
#Create a DataFrame df from this dictionary data which has the index labels.
df=pd.DataFrame(data,index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
#Display a summary of the basic information about this DataFrame and its data.
df.describe()
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   3.437500   1.900000
# std    2.007797   0.875595
# min    0.500000   1.000000
# 25%    2.375000   1.000000
# 50%    3.000000   2.000000
# 75%    4.625000   2.750000
# max    7.000000   3.000000

# %%
#information about each variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
# animal      10 non-null object
# age         8 non-null float64
# visits      10 non-null int64
# priority    10 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
#Return the first 3 rows of the DataFrame df.
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
#Select just the 'animal' and 'age' columns from the DataFrame.
df[['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
#Select the data in rows [3, 4, 8] and in columns ['animal', 'age'].
df.iloc[[3,4,8]][['animal','age']]
#df.iloc[[3,4,8],[0,1]]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %%
#Select only the rows where the number of visits is greater than 2.
df.query('visits>2')
#df[df['visits']>2]
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes
# d    dog  NaN       3      yes
# f    cat  2.0       3       no

# %%
#Select the rows where the age is missing, i.e. is NaN.
#count the missing values in the age variable
df[df['age'].isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df['age'].isnull().sum()
# Out:
# 2

# %%
df.query('age=="NaN"')
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
#Select the rows where the animal is a cat and the age is less than 3.
df[(df['animal']=='cat') & (df['age']<3)]
df.query('animal=="cat" & age <3')
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %%
##Select the rows the age is between 2 and 4 (inclusive).
df[df['age'].between(2,4)]
#df[(df['age']>=2) & (df['age']<4)]
#df.query('age>=2 & age<4')
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %%
#Change the age in row 'f' to 1.5.
df.loc['f','age']=1.5
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
#Calculate the sum of all visits (the total number of visits)
#df['visits'].sum()
df.visits.sum()
# Out:
# 19

# %%
#Calculate the mean age for each different animal in df.
df.groupby("animal",as_index=False).agg({'age':'mean'})
#df.groupby("animal",as_index=False)['animal','age'].mean()
# Out:
#   animal       age
# 0    cat  2.333333
# 1    dog  5.000000
# 2  snake  2.500000

# %%
#Count the number of each type of animal in df.
df['animal'].value_counts()
# Out:
# cat      4
# dog      4
# snake    2
# Name: animal, dtype: int64

# %%
#Sort df first by the values in the 'age' in decending order, then by the value in the 'visit' column in ascending order.
df.sort_values(['age','visits'],ascending=[False,True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# # Automobile data set

# %%
#import packages

# %%
#1.From the given data set print first and last five rows
# Out:
#    Unnamed: 0  index      company   body-style  wheel-base  length  \
# 0           0      0  alfa-romero  convertible        88.6   168.8
# 1           1      1  alfa-romero  convertible        88.6   168.8
#
#   engine-type num-of-cylinders  horsepower  average-mileage    price
# 0        dohc             four         111               21  13495.0
# 1        dohc             four         111               21  16500.0

# %%
#2. Check the data types of each variable
# Out:
# Unnamed: 0            int64
# index                 int64
# company              object
# body-style           object
# wheel-base          float64
# length              float64
# engine-type          object
# num-of-cylinders     object
# horsepower            int64
# average-mileage       int64
# price               float64
# dtype: object

# %%
#3. summary of the variables

# %%
#4. Count the missing values in a data frame

# %%
#5.Find the most expensive car company name
#auto.groupby('company').agg({'price':'max'}).sort_values('price',ascending=False).head(1)
#auto[['company','price']][auto.price==auto.price.max()]
auto[['company','price']].query('price==price.max()')
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
#7. print all Toyota cars details
auto.query('company=="toyota"')
#auto[auto['company']=='toyota']
# Out:
#     Unnamed: 0  index company body-style  wheel-base  length engine-type  \
# 48          48     66  toyota  hatchback        95.7   158.7         ohc
# 49          49     67  toyota  hatchback        95.7   158.7         ohc
# 50          50     68  toyota  hatchback        95.7   158.7         ohc
# 51          51     69  toyota      wagon        95.7   169.7         ohc
# 52          52     70  toyota      wagon        95.7   169.7         ohc
# 53          53     71  toyota      wagon        95.7   169.7         ohc
# 54          54     79  toyota      wagon       104.5   187.8        dohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 48             four          62               35   5348.0
# 49             four          62               31   6338.0
# 50             four          62               31   6488.0
# 51             four          62               31   6918.0
# 52             four          62               27   7898.0
# ...

# %%
#8. count total cars per company
auto['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# volkswagen       4
# mitsubishi       4
# audi             4
# mercedes-benz    4
# chevrolet        3
# jaguar           3
# isuzu            3
# porsche          3
# honda            3
# alfa-romero      3
# volvo            2
# dodge            2
# Name: company, dtype: int64

# %%
#9. Find each company's highest price car

# %%
#10 Find the average mileage of each car making company

# %%
#11. sort all cars by price column

# %% [markdown]
# # Chipotle data set from github

# %%
url="https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %%
# Import the necessary libraries

# %%
#Import the dataset from the given url
#Assign it to a variable called chipo.

# %%
#What is the price of each item?
#print a data frame with only two columns item_name and item_price

# %%
#Sort by the name of the item

# %%
#What was the quantity of the most expensive item ordered?

# %%
#How many times were a Veggie Salad Bowl ordered?

# %%
#How many times people orderd more than one Canned Soda?

# %% [markdown]
# # euro2 data set

# %%
#import packages

# %%
#load a dataset
#Assign it to a variable called euro12

# %%
pd.read_csv("D://Files//euro2.txt",sep=',')
# Out:
#                      Team  Goals  Shots\ton\ttarget  Shots\toff\ttarget  \
# 0                 Croatia      4                 13                  12
# 1         Czech\tRepublic      4                 13                  18
# 2                 Denmark      4                 10                  10
# 3                 England      5                 11                  18
# 4                  France      3                 22                  24
# 5                 Germany     10                 32                  32
# 6                  Greece      5                  8                  18
# 7                   Italy      6                 34                  45
# 8             Netherlands      2                 12                  36
# 9                  Poland      2                 15                  23
# 10               Portugal      6                 22                  42
# 11  Republic\tof\tIreland      1                  7                  12
# ...

# %%
#Select only the Goal column

# %%
#https://github.com/guipsamora/pandas_exercises/blob/master/02_Filtering_%26_Sorting/Fictional%20Army/Exercise.ipynb
